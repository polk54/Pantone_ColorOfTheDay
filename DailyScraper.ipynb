# %% [markdown]
# # Python Code for Creating Color Archive
#
# The purpose of this file is to scrape Pantone's Color of the Day website and create an archive of all the colors they've picked.
# https://www.pantone.com/colorstrology
#
# When run, this code will output three files:
#     1. Colors.csv
#     2. newcolor.html
#     3. index.html

# %% [markdown]
# ## Section 1
# Getting COTD info from Pantone's Color of the Day website and putting it into a csv.

# %%
from bs4 import BeautifulSoup, Tag, NavigableString
import requests

# %%
# Getting the url
url = requests.get("https://www.pantone.com/colorstrology")
url
# Out:
# <Response [200]>

# %%
# Getting the html of the website
soup = BeautifulSoup(url.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head id="ctl00_Head1">
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta charset="utf-8" content="text/html;" http-equiv="Content-Type"/>
#   <!-- meta format -->
#   <meta charset="utf-8"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- meta info -->
#   <meta content="PANTONE" name="author"/>
#   <meta content="Pantone LLC is a wholly owned subsidiary of X-Rite, Incorporated. Â© Pantone LLC, 2017. All rights reserved." name="copyright"/>
#   <!-- open graph -->
#   <meta content="https://www.pantone.com/colorstrology" name="og:url"/>
#   <meta content="website" name="og:type"/>
#   <meta content="Colorstrology - Pantone Color of the Day | Color Inspiration" name="og:title"/>
#   <meta content="https://www.pantone.com/images/seo/evergreen/Pantone-og.jpg" name="og:image"/>
#   <meta content="Partner with Pantone for color - and tools - that spark your inspiration and the facilitate accurate communication of colors. Color systems and technology." name="og:description"/>
#   <meta content="PANTONE" name="og:site_name"/>
#   <meta content="en_US" name="og:locale"/>
#   <meta content="223094864481571" name="fb:app_id"/>
#   <!-- twitter -->
#   <meta content="photo" name="twitter:card"/>
#   <meta content="@pantone" name="twitter:site"/>
#   <meta content="@pantone" name="twitter:creator"/>
#   <meta content="http://twitter.com/pantone" name="twitter:url"/>
#   <meta content="Colorstrology - Pantone Color of the Day | Color Inspiration" name="twitter:title"/>
#   <meta content="Partner with Pantone for color - and tools - that spark your inspiration and the facilitate accurate communication of colors. Color systems and technology." name="twitter:description"/>
#   <meta content="https://www.pantone.com/images/seo/evergreen/Pantone-og.jpg" name="twitter:image"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport">
#    <style>
#     html {overflow-x: hidden;}
#    </style>
#    <link href="/css/styles.min.css?ver=61317" rel="stylesheet" type="text/css"/>
#    <link href="/css/jquery.mCustomScrollbar.min.css" rel="stylesheet" type="text/css"/>
#    <script src="/scripts/modernizr.custom.min.js?ver=61317" type="text/javascript">
#    </script>
#    <script src="/scripts/Underscore.js?ver=61317">
#    </script>
#    <script src="/scripts/scripts.min.js?ver=61317" type="text/javascript">
#    </script>
#    <script language="JavaScript" src="/scripts/waypoints.min.js" type="text/JavaScript">
#    </script>
#    <script src="/scripts/jquery.mCustomScrollbar.concat.min.js">
#    </script>
#    <script>
#    </script>
#    <script>
#    </script>
#    <link href="/scripts/jquery-megamenu.2.1/stylesheets/pantone_menu_2013.min.css" rel="stylesheet" type="text/css"/>
#    <link href="/scripts/jquery-megamenu.2.1/stylesheets/jquery.megamenu_2013.min.css" rel="stylesheet" type="text/css"/>
#    <link href="/css/select2.min.css" rel="stylesheet" type="text/css"/>
#    <link href="/css/Pantone.Colorfinder.css" rel="stylesheet" type="text/css"/>
#    <style>
#     article.colorstrology:after {
#     width: 100%;
#     display: inline-block;
#     font-size: 0;
#     line-height: 0;
#     content: '';
#     zoom: 1;
# }
#
# article.colorstrology {
#     text-align: justify;
# }span.keyLogon {}
#
# .colorbg > div {
#     font-size: 26px;
#     display: inline-block;
#     padding-top: 10px;
# }
#
# span.colorbg {
#     display: inline-block;
# }
#
# .trendLinks {
#     width: 100%;
#     padding-top:10px;
#     font-size:16px;
#     color:#666;
#     display: inline-block;
# }
#
# article.colorstrology section.colorResult {
#     text-align: left;
#     padding-left: 255px;
#     display: inline-block;
#     position: relative;
#     vertical-align: top;
#     margin: 0;
# }
#
#
#
# .trendLinks >
#  a {
#     display: block;
# }
#
# article.colorstrology >div > section:before {
#     display: inline-block;
#     content: '';
#     width: 100%;
#     border-top: 1px #dfdfdf solid;
#     border-bottom:  none !important;
# }
#
# .pciAd {
#     display: inline-block;
#     float:right;
# }
#
# article.colorstrology > header {
#     width: 100%;
# }
#
# article.colorstrology > header h1 {
#     width: auto;
#     display: inline-block;
# }
#
# div#myPantone_SocialNetworkLikeButtons {
#     display: inline-block;
# }
#
#
#
# article.colorstrology header {
#     margin: 15px auto;
# }
# @media only screen and (max-width: 1200px)
# {
# .lrg .swatch div.pColorCode {
#     -webkit-box-sizing: content-box !important;
#     -moz-box-sizing: content-box !important;
#     box-sizing: content-box !important;
# }
# .productWrapper .tile.productItem.show, .swatches > div {
#     width: 45%;
# margin-bottom: 20px;
# }article.colorstrology section.colorResult{
#     padding: 154px 0;
#     padding-left: 0;
#     width: 100%;
# }span.colorBG{
#     position: absolute;
#     top: 0;
#     left: 0;
# }
# .trendLinks{
#     position: absolute;
#     bottom: 0;
#     left: 0;
# }.pciAd{
#     display: none;
# }.colorstrology section.colorResult .swatchContainer {
#     position: relative;
#     left: auto;
#     margin: auto;
#     display: block;
# }article.colorstrology > header h1{
#     font-size: 35px;
#     display: block;
# }
# div#outerWrap .wrapper{width:95%;}
#
# }
#
# span.colorBG {}
#    </style>
#    <link href="https://www.pantone.com/colorstrology" rel="canonical"/>
#    <link href="/css/Pantone.Responsive.min.css?ver=636543902515423700" rel="stylesheet" type="text/css"/>
#    <style type="text/css">
#     a.txtCatLineColor:visited,a.txtCatLineColor:link,a.txtCatLineColor:active{color:#E52525;}a.txtCatLineColor:hover{color:#8f8f8c;}
#    </style>
#    <!-- Google Tag Manager -->
#    <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-T3J3ZZW');
#    </script>
#    <!-- End Google Tag Manager -->
#    <script type="text/javascript">
#     var gaJsHost = ('https:' == document.location.protocol ? 'https://' : 'http://');
#     document.write(unescape("%3Cscript src='" + gaJsHost + "stats.g.doubleclick.net/dc.js' type='text/javascript'%3E%3C/script%3E"));
#    </script>
#    <div>
#     <script type="text/javascript">
#      var pageTracker = _gat._createTracker('UA-4720174-1');
#     var cookiePPVisit = getCookie("ppvisited");
#
#     if (cookiePPVisit == "") {
#         setCookie("ppvisited", JSON.stringify([0, "NA"]));
#         pageTracker._setCustomVar(1, "Visited Product Page(NA)", "No", 2);
#     }
#
#     pageTracker._trackPageview();
#     </script>
#    </div>
#    <title>
#     PANTONE Color of the Day
#    </title>
#    <script>
#     var w=window;if(w.performance||w.mozPerformance||w.msPerformance||w.webkitPerformance){var d=document;AKSB=w.AKSB||{},AKSB.q=AKSB.q||[],AKSB.mark=AKSB.mark||function(e,_){AKSB.q.push(["mark",e,_||(new Date).getTime()])},AKSB.measure=AKSB.measure||function(e,_,t){AKSB.q.push(["measure",e,_,t||(new Date).getTime()])},AKSB.done=AKSB.done||function(e){AKSB.q.push(["done",e])},AKSB.mark("firstbyte",(new Date).getTime()),AKSB.prof={custid:"347737",ustr:"",originlat:"0",clientrtt:"882",ghostip:"184.51.35.233",ipv6:false,pct:"10",clientip:"97.46.196.29",requestid:"6e081eb0",region:"18686",protocol:"",blver:13,akM:"b",akN:"ae",akTT:"O",akTX:"1",akTI:"6e081eb0",ai:"254600",ra:"false",pmgn:"",pmgi:"",pmp:"",qc:""},function(e){var _=d.createElement("script");_.async="async",_.src=e;var t=d.getElementsByTagName("script"),t=t[t.length-1];t.parentNode.insertBefore(_,t)}(("https:"===d.location.protocol?"https:":"http:")+"//ds-aksb-a.akamaihd.net/aksb.min.js")}
#    </script>
#   </meta>
#  </head>
#  <body>
#   <form action="/colorstrology" id="aspnetForm" method="post" name="aspnetForm">
#    <div>
#     <input id="_TSM_HiddenField_" name="_TSM_HiddenField_" type="hidden" value="28flvE0kbR4K35wJPhfEsgQVNseV8WRXMqb63pHzhx81"/>
#     <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwUJNDMyNDU0NjAzZGTPEngv4H6nzl+1QJtfwCt18E8QOw=="/>
#    </div>
#    <script src="/scripts/jquery-megamenu.2.1/javascripts/jquery.megamenu.min.js?ver=636543902515423700" type="text/javascript">
#    </script>
#    <script src="/scripts/jquery.select2.min.js" type="text/javascript">
#    </script>
#    <script src="/scripts/Pantone.Mobile.min.js?ver=636543902515423700" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=7_LIKDa-c9il-NjxeJUvv4njHKAuH_qY93TYQ3dWFwNdd4OehVq-2X_1z4bgcgiYkNp6XjMN94-oNBMKKnDBZpnc2r36lS01uzgv7d9yQSVUF5-j0&amp;t=ffffffffcda035a6" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     //<![CDATA[
# (window.Sys && Sys._Application && Sys.Observer)||document.write('<script type="text/javascript" src="/ScriptResource.axd?d=7_LIKDa-c9il-NjxeJUvv4njHKAuH_qY93TYQ3dWFwNdd4OehVq-2X_1z4bgcgiYkNp6XjMN94-oNBMKKnDBZpnc2r36lS01uzgv7d9yQSVUF5-j0&t=ffffffffcda035a6"><\/script>');//]]>
#    </script>
#    <script src="https://www.pantone.com/CombineScriptsHandler.axd?_TSM_CombinedScripts_=True&amp;v=28flvE0kbR4K35wJPhfEsgQVNseV8WRXMqb63pHzhx81&amp;_TSM_Bundles_=&amp;cdn=False" type="text/javascript">
#    </script>
#    <script src="webservices/webServices.asmx/js" type="text/javascript">
#    </script>
#    <div>
#     <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="90D17B1C"/>
#    </div>
#    <!-- Google Tag Manager (noscript) -->
#    <noscript>
#     <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T3J3ZZW" style="display:none;visibility:hidden" width="0">
#     </iframe>
#    </noscript>
#    <!-- End Google Tag Manager (noscript) -->
#    <div id="ctl00_LiveStats1_pnlStats">
#     <!-- Start of DeepMetrix (.NET) StatScript -->
#    </div>
#    <!--<div class="row-fluid siteWide-message">
#     <div class="containerCentered" style="padding: 0">
#         <div class="center-block">
#             <p>Due to scheduled maintenance, pantone.com will be unavailable from March 3, 6:00pm EST till March 5, 6:00pm EST.</p>
#         </div>
#     </div>
# </div>-->
#    <div class="updHDR" id="ctl00_ctlHeader_updHDR">
#     <a class="mobile-nav-search" href="javascript:void(0)" id="mobilenavsearch">
#      <i aria-hidden="true" class="fa fa-search">
#      </i>
#     </a>
#     <a class="mobile-nav-countries" href="/pages/shop/basket.aspx" id="mobilenavcountries" onclick="javascript:pageTracker._trackEvent('Top Navigation', 'View Cart','Click');">
#      <i aria-hidden="true" class="fa fa-cart-plus">
#      </i>
#     </a>
#     <header id="hdr">
#      <nav class="hdrNav" data-navcategoryid="2" id="ctl00_ctlHeader_hdrNav">
#       <style>
#        ul#main-menu {
#     padding-left: 30px !important;
# }
#       </style>
#       <ul id="main-menu" role="navigation">
#        <li id="nav_Shop">
#         <a class="" data-navcategoryid="1" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', 'Parent Level']});" rel="menuitem" role="button">
#          Shop
#         </a>
#         <div aria-labelledby="header-business" class="menu-wrapper" id="submenu-business" role="region" tabindex="-1">
#          <ul class="megamenu">
#           <li class="nav_Shop_all">
#            <ul class="mm-menu">
#             <li class="mm-menucol nmm">
#              <a class="mm-item-link" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', 'I work with... Parent']});">
#               <strong>
#                I work with...
#               </strong>
#              </a>
#              <ul class="menu-wrapper">
#               <li>
#                <a href="/material/packaging" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/material/packaging'] });">
#                 Packaging
#                </a>
#               </li>
#               <li>
#                <a href="/material/print" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/material/print'] });">
#                 Print
#                </a>
#               </li>
#               <li>
#                <a href="/material/digital" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/material/digital'] });">
#                 Digital
#                </a>
#               </li>
#               <li>
#                <a href="/material/textiles" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/material/textiles'] });">
#                 Textiles
#                </a>
#               </li>
#               <li>
#                <a href="/material/plastics" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/material/plastics'] });">
#                 Plastics
#                </a>
#               </li>
#               <li>
#                <a href="/material/coatings" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/material/coatings'] });">
#                 Coatings
#                </a>
#               </li>
#               <li>
#                <a href="/material/cosmetics" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/material/cosmetics'] });">
#                 Cosmetics
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="mm-menucol">
#              <a class="mm-item-link" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', 'I need tools for... Parent']});">
#               <strong>
#                I need tools for...
#               </strong>
#              </a>
#              <ul class="menu-wrapper">
#               <li>
#                <a href="/workflow/color-psychology" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/workflow/color-psychology'] });">
#                 Color Psychology
#                </a>
#               </li>
#               <li>
#                <a href="/workflow/trend-forecasting" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/workflow/color-psychology'] });">
#                 Trend Forecasting
#                </a>
#               </li>
#               <li>
#                <a href="/workflow/palette-development" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/workflow/palette-development'] });">
#                 Palette Development
#                </a>
#               </li>
#               <li>
#                <a href="/workflow/color-specification" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/workflow/color-specification'] });">
#                 Color Specification
#                </a>
#               </li>
#               <li>
#                <a href="/workflow/production-and-evaluation" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/workflow/production-and-evaluation'] });">
#                 Production &amp; Evaluation
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="mm-menucol">
#              <a class="mm-item-link" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', 'I am a... Parent']});">
#               <strong>
#                I am a...
#               </strong>
#              </a>
#              <ul class="menu-wrapper">
#               <li>
#                <a href="/persona/graphic-designer" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/persona/graphic-designer'] });">
#                 Graphic Designer
#                </a>
#               </li>
#               <li>
#                <a href="/persona/packaging-designer" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/persona/-designer'] });">
#                 Packaging Designer
#                </a>
#               </li>
#               <li>
#                <a href="/persona/fashion-designer" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/persona/fashion-designer'] });">
#                 Fashion Designer
#                </a>
#               </li>
#               <li>
#                <a href="/persona/interior-designer" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/persona/interior-designer'] });">
#                 Interior Designer
#                </a>
#               </li>
#               <li>
#                <a href="/persona/product-designer" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/persona/product-designer'] });">
#                 Product Designer
#                </a>
#               </li>
#               <li>
#                <a href="/persona/brand-manager" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/persona/brand-manager'] });">
#                 Brand Manager
#                </a>
#               </li>
#               <li>
#                <a href="/persona/printer" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/persona/printer'] });">
#                 Printer
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="mm-menucol">
#              <a class="mm-item-link" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', 'I need a product in... Parent']});">
#               <strong>
#                I need a product in...
#               </strong>
#              </a>
#              <ul class="menu-wrapper">
#               <li>
#                <a href="/pantone-lifestyle" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/pantone-lifestyle'] });">
#                 Pantone Lifestyle
#                </a>
#               </li>
#               <li>
#                <a href="/graphics" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/graphics'] });">
#                 Graphics
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-home-interiors" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/fashion-home-interiors'] });">
#                 Fashion, Home + Interiors
#                </a>
#               </li>
#               <li>
#                <a href="/plastics" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/plastics'] });">
#                 Plastics
#                </a>
#               </li>
#               <li>
#                <a href="/pantonelive-products" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/pantonelive-products']});">
#                 PantoneLIVE
#                </a>
#               </li>
#               <li>
#                <a href="/munsell" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/munsell'] });">
#                 Munsell
#                </a>
#               </li>
#               <li>
#                <a href="/color-control-tools" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/color-control'] });">
#                 Color Control Tools
#                </a>
#               </li>
#               <li>
#                <a href="/digital-apps" onclick="gaTracker({ 'event': ['Top Navigation', 'SHOP', '/digital-apps'] });">
#                 Digital Apps
#                </a>
#               </li>
#              </ul>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li>
#         <a class="" data-navcategoryid="2" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR SYSTEMS', 'Parent Level']});" rel="menuitem" role="button">
#          Color Systems
#         </a>
#         <div aria-labelledby="header-business" class="menu-wrapper" id="submenu-business" role="region" tabindex="-1">
#          <ul class="megamenu">
#           <li>
#            <a href="/color-systems-intro" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR SYSTEMS', '/color-systems-intro']});">
#             Pantone Color Systems Explained
#            </a>
#           </li>
#           <li>
#            <a href="/color-systems-graphics" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR SYSTEMS', '/color-systems-graphics']});">
#             For Graphic Design
#            </a>
#           </li>
#           <li>
#            <a href="/color-systems-fashion" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR SYSTEMS', '/color-systems-fashion']});">
#             For Fashion Design
#            </a>
#           </li>
#           <li>
#            <a href="/color-systems-product" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR SYSTEMS', '/color-systems-product']});">
#             For Product Design
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li>
#         <a class="header-item" data-navcategoryid="3" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', 'Parent Level']});" rel="menuitem" role="button">
#          Color Intelligence
#         </a>
#         <div aria-labelledby="header-business" class="menu-wrapper" id="submenu-business" role="region" tabindex="-1">
#          <ul class="megamenu">
#           <li>
#            <a href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', 'Color of the Year... Parent']});">
#             Color of the Year
#            </a>
#            <div class="mm-menu">
#             <div class="mm-menucol nmm">
#              <ul>
#               <li>
#                <a href="/color-of-the-year-2018" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2018'] });">
#                 2018: Ultra Violet
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2017" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2017'] });">
#                 2017: Greenery
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2016" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2016'] });">
#                 2016: Rose Quartz &amp; Serenity
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2015" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2015'] });">
#                 2015: Marsala
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2014" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2014'] });">
#                 2014: Radiant Orchid
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2013" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2013'] });">
#                 2013: Emerald
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2012" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2012'] });">
#                 2012: Tangerine Tango
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2011" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2011'] });">
#                 2011: Honeysuckle
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2010" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2010'] });">
#                 2010: Turquoise
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2009" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2009'] });">
#                 2009: Mimosa
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2008" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2008'] });">
#                 2008: Blue Iris
#                </a>
#               </li>
#               <li>
#                <a href="/color-of-the-year-2007" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-of-the-year-2007'] });">
#                 2007: Chili Pepper
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#           <li>
#            <a href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', 'Fashion Color Trend Report... Parent']});">
#             Fashion Color Trend Report
#            </a>
#            <div class="mm-menu">
#             <div class="mm-menucol nmm">
#              <ul>
#               <li>
#                <a href="/fashion-color-trend-report-london-autumn-winter-2018" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-trend-report-london-autumn-winter-2018'] });">
#                 Autumn/Winter 2018 - London
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-color-trend-report-new-york-fall-winter-2018" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-trend-report-new-york-fall-winter-2018'] });">
#                 Fall/Winter 2018 - New York
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-color-trend-report-new-york-spring-2018" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-trend-report-new-york-spring-2018'] });">
#                 Spring 2018 - New York
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-color-trend-report-london-spring-2018" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-trend-report-london-spring-2018'] });">
#                 Spring 2018 - London
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-color-report-fall-2017" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-report-fall-2017'] });">
#                 Fall 2017
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-color-report-spring-2017" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-report-spring-2017'] });">
#                 Spring 2017
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-color-report-fall-2016" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-report-fall-2016'] });">
#                 Fall 2016
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-color-report-spring-2016" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-color-report-spring-2016'] });">
#                 Spring 2016
#                </a>
#               </li>
#               <li>
#                <a href="/pages/fcr/default.aspx?season=fall&amp;year=2015" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/pages/fcr/default.aspx?season=fall&amp;year=2015'] });">
#                 Fall 2015
#                </a>
#               </li>
#               <li>
#                <a href="/pages/fcr/default.aspx?season=spring&amp;year=2015" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/pages/fcr/default.aspx?season=spring&amp;year=2015'] });">
#                 Spring 2015
#                </a>
#               </li>
#               <li>
#                <a href="/pages/fcr/?season=fall&amp;year=2014" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/pages/fcr/?season=fall&amp;year=2014'] });">
#                 Fall 2014
#                </a>
#               </li>
#               <li>
#                <a href="/pages/fcr/?season=spring&amp;year=2014" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/pages/fcr/?season=spring&amp;year=2014'] });">
#                 Spring 2014
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#           <li class="nav_Shop_all">
#            <a href="/articles" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/articles'] });">
#             Articles
#            </a>
#           </li>
#           <li>
#            <a href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', 'Color Reference... Parent']});">
#             Color Reference
#            </a>
#            <div class="mm-menu">
#             <div class="mm-menucol nmm">
#              <ul>
#               <li>
#                <a href="/color-finder" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-finder'] });">
#                 Find a Pantone Color
#                </a>
#               </li>
#               <li>
#                <a href="/x-ref" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/x-ref'] });">
#                 Color Cross-Reference
#                </a>
#               </li>
#               <li>
#                <a href="/colorstrology" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/colorstrology'] });">
#                 Color of the Day
#                </a>
#               </li>
#               <li>
#                <a href="/what-is-extended-gamut" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/what-is-extended-gamut'] });">
#                 What is Extended Gamut?
#                </a>
#               </li>
#               <li>
#                <a href="/color-systems-graphic-design-workflow" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-systems-graphic-design-workflow'] });">
#                 The Graphic Design Workflow
#                </a>
#               </li>
#               <li>
#                <a href="/color-systems-fashion-design-workflow" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-systems-fashion-design-workflow'] });">
#                 The Fashion Design Workflow
#                </a>
#               </li>
#               <li>
#                <a href="/color-systems-product-design-workflow" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/color-systems-product-design-workflow'] });">
#                 The Product Design Workflow
#                </a>
#               </li>
#               <li>
#                <a href="/112-graphics-colors-2016" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/112-graphics-colors-2016'] });">
#                 New Colors, New Possibilities (Our Graphics System)
#                </a>
#               </li>
#               <li>
#                <a href="/210-fashion-home-interiors-colors-2016" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/210-fashion-home-interiors-colors-2016'] });">
#                 210 New Shades (Our FHI System)
#                </a>
#               </li>
#               <li>
#                <a href="/graphic-designers" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/graphic-designers'] });">
#                 Tools to Help You Get Your Color Right Across All Materials (Graphic Designers)
#                </a>
#               </li>
#               <li>
#                <a href="/fashion-designers" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/fashion-designers'] });">
#                 Tools to Help You Get Your Color Right Across All Materials (Fashion Designers)
#                </a>
#               </li>
#               <li>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#           <li>
#            <a href="/events-webinars" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR INTELLIGENCE', '/events-webinars'] });">
#             Events &amp; Webinars
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li>
#         <a class="" data-navcategoryid="4" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR CONSULTING', 'Parent Level']});" rel="menuitem" role="button">
#          Color Consulting
#         </a>
#         <div aria-labelledby="header-business" class="menu-wrapper" id="submenu-business" role="region" tabindex="-1">
#          <ul class="megamenu">
#           <li>
#            <a href="/pci" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR CONSULTING', '/pci']});">
#             About Pantone Color Institute
#             <sup style="font-size: .45em; vertical-align: top;">
#              TM
#             </sup>
#            </a>
#           </li>
#           <li>
#            <a href="/custom-brand-color" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR CONSULTING', '/custom-brand-color']});">
#             Custom Brand Colors
#            </a>
#           </li>
#           <li>
#            <a href="/pantone-color-institute-brand-and-product-custom-color-solutions" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR CONSULTING', '/pantone-color-institute-brand-and-product-custom-color-solutions']});">
#             Custom Color Solutions
#            </a>
#           </li>
#           <li>
#            <a href="/trend-forecasting" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR CONSULTING', '/trend-forecasting']});">
#             Trend Forecast Products
#            </a>
#           </li>
#           <li>
#            <a href="/pantone-custom-brand-color-directory" onclick="gaTracker({ 'event': ['Top Navigation', 'COLOR CONSULTING', '/pantone-custom-brand-color-directory']});">
#             Brand Color Directory
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li>
#         <a class="" data-navcategoryid="5" href="javascript:void(0)" onclick="gaTracker({ 'event': ['Top Navigation', 'LICENSEES', 'Parent Level']});" rel="menuitem" role="button">
#          Licensees
#         </a>
#         <div aria-labelledby="header-business" class="menu-wrapper" id="submenu-business" role="region" tabindex="-1">
#          <ul class="megamenu">
#           <li>
#            <a href="/consumer-licensees" onclick="gaTracker({ 'event': ['Top Navigation', 'LICENSEES', '/consumer-licensees'] });">
#             Consumer Licensees
#            </a>
#           </li>
#           <li>
#            <a href="/find-a-licensee" onclick="gaTracker({ 'event': ['Top Navigation', 'LICENSEES', '/find-a-licensee'] });">
#             Find a Licensee
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </nav>
#      <div id="pnlBasketView">
#       <script type="text/javascript">
#        // This function calls the Web Service method.
#         function GetCartItems(basketID) {
#             var echoElem = document.getElementById("EnteredValue");
#             Pantone.webServices.GetCartItems(basketID,
#                 SucceededCallback);
#         }
#
#         // This is the callback function that
#         // processes the Web Service return value.
#         function SucceededCallback(result) {
#             var RsltElem = document.getElementById("Results");
#             RsltElem.innerHTML = result;
#         }
#       </script>
#       <script type="text/javascript">
#        function BeginRequest(sender, args) {
#             try {
#                 args.get_request().set_userContext(args.get_postBackElement().id);
#             }
#             catch (e) {
#             }
#         }
#         function EndRequest(sender, args) {
#             var requestor;
#             try {
#                 if (args.get_error() == undefined)
#                     requestor = args.get_response().get_webRequest().get_userContext();
#             }
#             catch (e) {
#             }
#             if (requestor == "ctl00_ctlHeader_ctlBasketLite_buttonUpd")
#                 jQuery('ul#ecomLite').find('li.navRight > ul').find('li:not(.shopping_cart)').addClass('show');
#
#         }
#
#         (function ($) {
#             $(window).load(function () {
#                 //if ($('#updMemberLogin').length)
#                 //__doPostBack('updMemberLogin', '');
#             });
#
#             $(document).ready(function () {
#                 if (document.location.pathname.toLowerCase().indexOf("/pages/shop/basket.aspx") < 0) {
#                     var prm = Sys.WebForms.PageRequestManager.getInstance();
#                     prm.add_beginRequest(BeginRequest);
#                     prm.add_endRequest(EndRequest);
#                     if ($('#updMemberLogin').length){
#                                                           var clickButton = document.getElementById("ctl00_ctlHeader_ctlBasketLite_buttonUpd");
#                     clickButton.click();}
#                 }
#             });
#         })(jQuery)
#       </script>
#       <ul id="ecomLite">
#        <li class="navLeft">
#         <ul>
#          <li class="sites">
#           <script language="javascript">
#            function surfto2(e) { var myindex=e.selectedIndex; if (e.options[myindex].value != "0") { location=e.options[myindex].value;} }
#           </script>
#           <select id="siteDropDown" name="siteSelect" onchange="surfto2(this)">
#            <option class="siteTitle" disabled="disabled" selected="selected">
#             United States
#            </option>
#            <optgroup class="globalSites">
#             <option value="http://store.pantone.com/hk/en/">
#              Australia
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Austria
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Bangladesh
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Belgium
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Bosnia &amp; Herzegowina
#             </option>
#             <option value="http://www.pantonebr.com.br">
#              Brazil
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Bulgaria
#             </option>
#             <option value="http://www.pantone.com">
#              Canada
#             </option>
#             <option value="http://store.pantone.com/es/es">
#              Canary Islands
#             </option>
#             <option value="http://store.pantone.com/hk/tc/">
#              China
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Croatia
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Cyprus
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Czech Republic
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Denmark
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Estonia
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Finland
#             </option>
#             <option value="http://store.pantone.com/fr/fr">
#              France
#             </option>
#             <option value="http://store.pantone.com/de/de/">
#              Germany
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Greece
#             </option>
#             <option value="http://store.pantone.com/hk/tc/">
#              Hong Kong S.A.R.
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Hungary
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              India
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Indonesia
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Ireland
#             </option>
#             <option value="http://store.pantone.com/it/it">
#              Italy
#             </option>
#             <option value="http://www.pantone.jp">
#              Japan
#             </option>
#             <option value="http://www.pantone.kr">
#              Korea
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Latvia
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Lithuania
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Luxembourg
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Malaysia
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Malta
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Netherlands
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              New Zealand
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Pakistan
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Philippines
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Poland
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Portugal
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Romania
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Singapore
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Slovakia
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Slovenia
#             </option>
#             <option value="http://store.pantone.com/es/es">
#              Spain
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Sri Lanka
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Sweden
#             </option>
#             <option value="http://store.pantone.com/eu/en/">
#              Switzerland
#             </option>
#             <option value="http://store.pantone.com/hk/tc/">
#              Taiwan
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Thailand
#             </option>
#             <option value="http://store.pantone.com/uk/en/">
#              United Kingdom
#             </option>
#             <option value="http://store.pantone.com/hk/en/">
#              Vietnam
#             </option>
#            </optgroup>
#           </select>
#           <ul id="siteDropDown">
#            <li>
#             <a class="header-item siteTitle" href="javascript:void(0)">
#              <img class="img-flag" data-pin-nopin="true" src="/images/flags/United_States.png"/>
#              <span>
#               United States
#              </span>
#             </a>
#             <ul class="globalSites">
#             </ul>
#            </li>
#           </ul>
#          </li>
#          <li class="current" itemprop="telephone" onclick="gaTracker({'event': ['Top Black Bar', '1 888-PANTONE', 'Telephone']});">
#           <a href="tel:+18887268663">
#            +1 888-PANTONE
#           </a>
#          </li>
#          <li class="current" onclick="gaTracker({'event': ['Top Black Bar', 'Contact Us', '/pages/pantone/pantone.aspx?pg=19311&amp;ca=10']});">
#           <a href="/pages/pantone/pantone.aspx?pg=19311&amp;ca=10" title="Contact Us">
#            Contact Us
#           </a>
#          </li>
#          <li class="current" onclick="gaTracker({'event': ['Top Black Bar', 'Get Pantone.com News &amp; Promotions', 'Pop Up']});">
#           <span class="angle-right">
#            <a onclick="initiateSignUp('Header');">
#             Get Pantone.com News &amp; Promotions
#            </a>
#           </span>
#          </li>
#          <div id="ctl00_ctlHeader_ctlBasketLite_ctlHdrLinks_divPhLinesDown">
#          </div>
#         </ul>
#        </li>
#        <li class="navRight">
#         <ul id="ctl00_ctlHeader_ctlBasketLite_trLine1">
#          <li id="ctl00_ctlHeader_ctlBasketLite_liMemberLogin">
#           <div id="updMemberLogin">
#            <a href="/pages/myPantone/myPantone.aspx" id="ctl00_ctlHeader_ctlBasketLite_cmdMemberLogin" onclick="javascript:pageTracker._trackEvent('Top Navigation', 'LOGIN','Click');" target="_blank">
#             Sign In
#            </a>
#            <button id="ctl00_ctlHeader_ctlBasketLite_buttonUpd" style="display:none;">
#            </button>
#           </div>
#          </li>
#          <li id="liRegister">
#           <div id="ctl00_ctlHeader_ctlBasketLite_updRegister">
#            /
#            <a href="/pages/MYP_myPantone/mypMemberProfile.aspx" id="ctl00_ctlHeader_ctlBasketLite_cmdRegister" target="_blank">
#             Register
#            </a>
#           </div>
#          </li>
#          <li class="shopping_cart">
#           <div id="ctl00_ctlHeader_ctlBasketLite_updcartInfo">
#            <div id="dvCart">
#             <span class="template12">
#              <div id="dvBasketInfo" style="display: none;">
#               <div id="dvBasketInfoInner">
#                <span class="title">
#                </span>
#                <hr class="menuContainerSeparator"/>
#                <div style="height: 10px;">
#                </div>
#                <div id="itemsWrap" style="display: none;">
#                 <div style="margin-top: 10px;">
#                  <div style="float: right;">
#                   <strong data-bind="text: ['Subtotal: $', $root.subTotal()].join('')" style="padding-right: 9px;">
#                    Subtotal: $0
#                   </strong>
#                  </div>
#                  <div style="clear: both; height: 5px;">
#                  </div>
#                  <div style="float: right;">
#                   <a href="">
#                    <img alt="Checkout" src=""/>
#                   </a>
#                  </div>
#                  <div style="clear: both;">
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </span>
#            </div>
#            <a class="emptyCart" href="/pages/shop/basket.aspx" id="ctl00_ctlHeader_ctlBasketLite_cmdViewOrder" onclick="javascript:pageTracker._trackEvent('Top Navigation', 'View Cart','Click');">
#             <i aria-hidden="true" class="fa fa-cart-plus">
#             </i>
#             <div class="template11 itemsCartCount">
#             </div>
#            </a>
#            <div class="emptyCart" id="divItemsCartSubtotal" onclick="">
#             $0.00
#            </div>
#           </div>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#      <section class="row-fluid footer">
#       <div class="wrapperFooter containerCentered">
#        <!-- Dummy Content for now [test]-->
#        <div style="display: none; position: relative; width: 300px; top: -70px; height: 40px; margin: 0px; padding: 0px;">
#         <div id="ctl00_ctlFooter_ColorstrologyHomePageInsert1_plColorstrologyBackgroundPanel" style="background-color:#BBA0CE;">
#          <a href="/pages/colorstrology/colorstrology.aspx" style="text-decoration:none;display:block;cursor:hand;">
#           <div class="colorFooter" id="colorFooter">
#            <span class="txtFooter">
#             color of the day:
#             <br/>
#            </span>
#            <span class="nameFooter">
#             Lavendula     15-3620
#            </span>
#           </div>
#          </a>
#         </div>
#         <span class="colorFooterLinks">
#          <span>
#           <a href="http://www.colorstrology.com" style="text-decoration:none;" target="_blank">
#            /Colorstrology
#           </a>
#          </span>
#          <span style="padding-left:25px;">
#           <a href="http://www.pantoneuniverse.com" style="text-decoration:none;" target="_blank">
#            /PANTONE UNIVERSE
#           </a>
#          </span>
#         </span>
#        </div>
#        <!-- SOCIAL MEDIA WRAPPER -->
#        <link href="/css/style_slide.css" rel="stylesheet" type="text/css"/>
#        <link href="/css/styles.vs.min.css" rel="stylesheet" type="text/css"/>
#        <script type="text/javascript">
#         function setStyle(iState, oSpan, sCSS) {
#         if (iState == 1) {
#             //mouseover
#             oSpan.className = "rssplain";
#         }
#         else {
#             //mouseout
#             oSpan.className = sCSS;
#         }
#     }
#        </script>
#        <div id="ftrwrapper">
#         <div class="groupleft">
#          <div class="pnlHeaderSocialIcons" id="ctl00_ctlFooter_cntrlSMW_pnlSocialIcons">
#           <h5 class="">
#            Stay Connected:
#           </h5>
#           <a class="icon-twitter-2" href="https://twitter.com/PANTONE" onclick="gaTracker({'event':['Footer','Social Media','Twitter']});" target="_blank">
# ...
#          </a>
#         </li>
#         <li>
#          <a href="/find-a-licensee" onclick="gaTracker({ 'event': ['Footer', 'SERVICES', '/find-a-licensee'] });">
#           Find a Licensee
#          </a>
#         </li>
#         <li>
#          <a href="/find-a-dealer" onclick="gaTracker({ 'event': ['Footer', 'SERVICES', '/find-a-dealer'] });">
#           Find a Dealer
#          </a>
#         </li>
#        </div>
#        <div class="ftrframe-nav-group">
#         <h5>
#          CUSTOMER SERVICE
#         </h5>
#         <li>
#          <a href="/help" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/help'] });">
#           Help Center
#          </a>
#         </li>
#         <li>
#          <a href="/color-finder" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/color-finder'] });">
#           Find a Pantone Color
#          </a>
#         </li>
#         <li>
#          <a href="/x-ref" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/x-ref'] });">
#           Color Cross-Reference
#          </a>
#         </li>
#         <li>
#          <a href="/pages/MYP_myPantone/mypantone.aspx" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/pages/MYP_myPantone/mypantone.aspx(Member Login/Logout)'] });">
#           Member Login/Logout
#          </a>
#         </li>
#         <li>
#          <a href="/pages/MYP_myPantone/mypMemberProfile.aspx" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/pages/MYP_myPantone/mypMemberProfile.aspx (Member Registration)'] });">
#           Member Registration
#          </a>
#         </li>
#         <li>
#          <a href="/pages/MYP_myPantone/mypMemberProfile.aspx" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/pages/MYP_myPantone/mypMemberProfile.aspx (Member Account Details)'] });">
#           Member Account Details
#          </a>
#         </li>
#         <li>
#          <a href="/pages/MYP_myPantone/GetYourPassword.aspx" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/pages/MYP_myPantone/GetYourPassword.aspx'] });">
#           Member Reset Password
#          </a>
#         </li>
#        </div>
#        <div class="ftrframe-nav-group">
#         <span>
#         </span>
#         <li>
#          <a href="/pages/MYP_myPantone/mypProductRegistration.aspx" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '//pages/MYP_myPantone/mypProductRegistration.aspx'] });">
#           Product Registration
#          </a>
#         </li>
#         <li>
#          <a href="/pantone-software-downloads" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/pantone-software-downloads'] });">
#           Software Downloads
#          </a>
#         </li>
#         <li>
#          <a href="/pages/aboutUs/contactus.aspx?Department=8" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/pages/aboutUs/contactus.aspx?Department=8'] });">
#           Ask a Question
#          </a>
#         </li>
#         <li>
#          <a href="/return-policy" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/return-policy'] });">
#           Returns
#          </a>
#         </li>
#         <li>
#          <a href="/downloads/catalogs/PANTONE-full-line-color-standards-tools-catalog-2016.pdf" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/downloads/catalogs/PANTONE-full-line-color-standards-tools-catalog-2016.pdf'] });">
#           Download Catalog
#          </a>
#         </li>
#         <li>
#          <a href="/digital-wallpaper" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/digital-wallpaper'] });">
#           Digital Wallpaper
#          </a>
#         </li>
#         <li>
#          <a href="/contact-us" onclick="gaTracker({ 'event': ['Footer', 'CUSTOMER SERVICE', '/contact'] });">
#           Contact Us
#          </a>
#         </li>
#        </div>
#       </div>
#       <div class="groupright" style="display:none;">
#        <script language="javascript">
#         function surfto2(e) { var myindex=e.selectedIndex; if (e.options[myindex].value != "0") { location=e.options[myindex].value;} }
#        </script>
#        <select id="siteDropDown" name="siteSelect" onchange="surfto2(this)">
#         <option class="siteTitle" disabled="disabled" selected="selected">
#          United States
#         </option>
#         <optgroup class="globalSites">
#          <option value="http://store.pantone.com/hk/en/">
#           Australia
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Austria
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Bangladesh
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Belgium
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Bosnia &amp; Herzegowina
#          </option>
#          <option value="http://www.pantonebr.com.br">
#           Brazil
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Bulgaria
#          </option>
#          <option value="http://www.pantone.com">
#           Canada
#          </option>
#          <option value="http://store.pantone.com/es/es">
#           Canary Islands
#          </option>
#          <option value="http://store.pantone.com/hk/tc/">
#           China
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Croatia
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Cyprus
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Czech Republic
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Denmark
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Estonia
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Finland
#          </option>
#          <option value="http://store.pantone.com/fr/fr">
#           France
#          </option>
#          <option value="http://store.pantone.com/de/de/">
#           Germany
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Greece
#          </option>
#          <option value="http://store.pantone.com/hk/tc/">
#           Hong Kong S.A.R.
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Hungary
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           India
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Indonesia
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Ireland
#          </option>
#          <option value="http://store.pantone.com/it/it">
#           Italy
#          </option>
#          <option value="http://www.pantone.jp">
#           Japan
#          </option>
#          <option value="http://www.pantone.kr">
#           Korea
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Latvia
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Lithuania
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Luxembourg
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Malaysia
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Malta
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Netherlands
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           New Zealand
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Pakistan
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Philippines
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Poland
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Portugal
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Romania
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Singapore
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Slovakia
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Slovenia
#          </option>
#          <option value="http://store.pantone.com/es/es">
#           Spain
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Sri Lanka
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Sweden
#          </option>
#          <option value="http://store.pantone.com/eu/en/">
#           Switzerland
#          </option>
#          <option value="http://store.pantone.com/hk/tc/">
#           Taiwan
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Thailand
#          </option>
#          <option value="http://store.pantone.com/uk/en/">
#           United Kingdom
#          </option>
#          <option value="http://store.pantone.com/hk/en/">
#           Vietnam
#          </option>
#         </optgroup>
#        </select>
#        <ul id="siteDropDown">
#         <li>
#          <a class="header-item siteTitle" href="javascript:void(0)">
#           <img class="img-flag" data-pin-nopin="true" src="/images/flags/United_States.png"/>
#           <span>
#            United States
#           </span>
#          </a>
#          <ul class="globalSites">
#          </ul>
#         </li>
#        </ul>
#        <!-- Moods Widget Begin -->
#        <div id="ctl00_ctlFooter_cntrlSMW_pnlMoodsWidget">
#        </div>
#        <!-- Moods Widget End -->
#        <!-- myPantone Content Begin -->
#        <!-- myPantone Content End -->
#        <div class="clear">
#        </div>
#       </div>
#      </div>
#      <!--end mainwrapper -->
#      <!-- Live Person -->
#      <br clear="all"/>
#      <span style="color: #FFFFFF;">
#       S2
#      </span>
#     </div>
#    </section>
#    <div id="modalPanel">
#     <div class="modal_window genericModal" id="genericModal">
#      <div class="quickView_tlc qvbg">
#      </div>
#      <div class="quickView_trc qvbg">
#      </div>
#      <div class="quickView_top qvbg">
#      </div>
#      <div class="quickView_left qvbg">
#      </div>
#      <div class="quickView_right qvbg">
#      </div>
#      <div class="modalTitle">
#       <h2>
#       </h2>
#      </div>
#      <div class="modal_content">
#      </div>
#      <div id="modalBot">
#       <div class="quickView_blc">
#       </div>
#       <div class="quickView_brc">
#       </div>
#       <div class="quickView_bottom">
#       </div>
#      </div>
#      <div class="closeBtn">
#       <a class="close_modal fa fa-close" href="javascript:void(0)">
#        close
#       </a>
#      </div>
#     </div>
#    </div>
#    <div id="mask">
#    </div>
#    <script type="text/javascript">
#     //<![CDATA[
#
#     (function ($) {
#         $('#hdr').find('#siteDropDown').select2({
#             templateResult: formatSiteCountryDD,
#             templateSelection:formatSiteCountryDD,
#             dropdownParent: $('#ctl00_ctlHeader_updHDR'),
# width: "auto",
#                     dropdownAutoWidth: true
#         });
#         $.PANTONE.miniMegaNav = {
#
#             // Randomizer to load in mini-MegaNav banners. RJP
#             // !important is necessary to override the background image declared in the master CSS.
#
#             // Add Image file names and their respective hotlinks to the images object array.
#             // dateAdded is unused and only for reference.
#             // To do - write logic to utilize the expiry date to automate disabling the asset.
#             images: [
#
#                            {
#                                imageFile: 'Pantone-Color-Institute-450x100.jpg',
#                                hotlink: '/pci',
#                                dateAdded: '2015-06-23',
#                                expiry: ''
#                            },
#                            {
#                                imageFile: 'Pantone-Trade-In-450x100.jpg',
#                                hotlink: '/trade-in-program',
#                                dateAdded: '2015-06-23',
#                                expiry: ''
#                            },
#                            {
#                                imageFile: 'Pantone-Special-Offers.jpg',
#                                hotlink: '/special-offers',
#                                dateAdded: '2015-06-24',
#                                expiry: ''
#                            },
#                            {
#                                imageFile: 'Extended-Gamut-Guide-Graphics-Pantone-MegaNav.jpg',
#                                hotlink: '/what-is-extended-gamut',
#                                dateAdded: '2015-09-01',
#                                expiry: ''
#                            },
#                            {
#                                imageFile: 'Pantone-112-New-Colors-For-Graphic-Design-New-Colors-New-Possibillities-Meganav.jpg',
#                                hotlink: '/112-graphics-colors-2016',
#                                dateAdded: '2016-02-26',
#                                expiry: ''
#                            },
#                            {
#                                imageFile: 'Fashion-Home-Interiors-2016-New-Colors-Paper-Cotton-Landing-Page-Meganav.jpg',
#                                hotlink: '/pages/Pantone.aspx?pg=21262&ca=4',
#                                dateAdded: '2016-04-04',
#                                expiry: ''
#                            },
#                            {
#                                imageFile: 'Pantone-Studio-App-For-iOS-MegaNav.jpg',
#                                hotlink: 'https://itunes.apple.com/app/apple-store/id329515634?pt=216826&ct=naMegaNav&mt=8',
#                                dateAdded: '2016-08-02',
#                                expiry: ''
#                            },
#                            {
#                                imageFile: 'Pantone-Studio-App-For-iOS-MegaNav.jpg',
#                                hotlink: 'https://itunes.apple.com/app/apple-store/id329515634?pt=216826&ct=naMegaNav&mt=8',
#                                dateAdded: '2016-08-02',
#                                expiry: ''
#                            }
#             ]
#         }
#     })(jQuery);
# (function ($) {jQuery('.megamenu').megamenu();  })(jQuery);//]]>
#    </script>
#   </form>
#   <font color="white">
#    CartID: 366844799
#    <br/>
#    RemoteIP: 97.46.196.29
#    <br/>
#    PageID : 20062
#   </font>
#   <!-- Google Code for Remarketing Tag -->
#   <!--------------------------------------------------
# Remarketing tags may not be associated with personally identifiable information or placed on pages related to sensitive categories. See more information and instructions on how to setup the tag on: http://google.com/ads/remarketingsetup
# --------------------------------------------------->
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var google_conversion_id = 993586654;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/993586654/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1">
#     </img>
#    </div>
#   </noscript>
#   <!-- BEGIN: Google Trusted Stores -->
#   <script type="text/javascript">
#    var gts = gts || [];
#
# gts.push(['id', '563656']);
# gts.push(['badge_position', 'BOTTOM_RIGHT']);
# gts.push(['locale', 'en_US']);
#
# (function() {
#   var gts = document.createElement('script');
#   gts.type = 'text/javascript';
#   gts.async = true;
#   gts.src = 'https://www.googlecommerce.com/trustedstores/api/js';
#   var s = document.getElementsByTagName('script')[0];
#   s.parentNode.insertBefore(gts, s);
# })();
#   </script>
#   <!-- END: Google Trusted Stores -->
#   <img border="0" height="1" src="https://s.amazon-adsystem.com/iui3?d=3p-hbg&amp;ex-src=pantone.com&amp;ex-hargs=v%3D1.0%3Bc%3D3229416366894%3Bp%3DH" width="1"/>
#  </body>
# </html>

# %%
# I need:
# <div class="swatch inner" title="Pantone 15-1607 Pale Mauve">
# <div class="coloredSquare" style="background-color: #C5A4A4;">
# <span class="keyLogon"> HARDWORKING </span>
# <span class="keyLogon"> CARING </span>
# <span class="keyLogon"> PREPARED </span>

# %%
# Getting html in the div element
div = soup.find(id="outerWrap")

# %%
# Drilling down further
div2 = div.find(id="ctl00_divBody")

# %%
# Finding specific div for color - doesn't have the 3 words
Color = div.find(class_="swatch inner")
print(Color.prettify())
# Out:
# <div class="swatch inner" title="Pantone 15-3620 Lavendula">
#  <div class="coloredSquare" style="background-color: #BBA0CE;">
#  </div>
#  <div class="darkFore pantoneInfo">
#   <span class="pLogo">
#   </span>
#   <div class="pColorCode">
#    <svg height="100%" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 500 125" width="100%" xmlns="http://www.w3.org/2000/svg">
#     <text fill="black" font-family="helvmd,Helvetica,sans-serif" font-size="60" x="30" y="0">
#      15-3620
#     </text>
#     <text fill="black" font-family="helvmd,Helvetica,sans-serif" font-size="60" x="30" y="70">
#      Lavendula
#     </text>
#    </svg>
#   </div>
#  </div>
# </div>

# %%
# Print the entire color name from the HTML
ColorName = Color["title"]
print (ColorName)
# Out:
# Pantone 15-3620 Lavendula

# %%
# Separate PantoneID
PantoneID = ColorName[8:15]
print(PantoneID)
# Out:
# 15-3620

# %%
# Separate Pantone Color Name
PantoneName = ColorName[16:]
print(PantoneName)
# Out:
# Lavendula

# %%
# Separate background color
ID = div.find(class_="coloredSquare")
ColorID = ID["style"]
print (ColorID)
# Out:
# background-color: #BBA0CE;

# %%
# Separate hex code
Hex = ColorID[18:25]
print (Hex)
# Out:
# #BBA0CE

# %%
# Getting the 3 words
Text = div2.find("span",{"class":"keyLogon"})
print(Text.get_text())
# Out:
# POWERFUL

# %%
# need to figure out how to get the next two words.

# %%
for wrapper in div2.find_all("span",{"class":"keyLogon"}):
    print(wrapper.text)
# Out:
# POWERFUL
# THEATRICAL
# DRIVEN

# %%
# Puts the three words into a list
text = []    
for wrapper in div2.find_all("span",{"class":"keyLogon"}):
    wrapper = wrapper.get_text()
    text.append(wrapper)
print(text)
# Out:
# ['POWERFUL    ', 'THEATRICAL    ', 'DRIVEN    ']

# %%
# Gets rid of the trailing space
text = [x.strip(' ') for x in text]
print(text)
# Out:
# ['POWERFUL', 'THEATRICAL', 'DRIVEN']

# %%
# Separate list into 3 string variables and makes them all lowercase
Word1 = text[0]
Word1 = str.lower(Word1)
Word2 = text[1]
Word2 = str.lower(Word2)
Word3 = text[2]
Word3 = str.lower(Word3)

# %%
# Creating the date variable
import datetime
from datetime import date
today = datetime.date.today()
today = (today.strftime("%m/%d/%Y"))
print (today)
# Out:
# 02/16/2018

# %%
# Appends all the scraped items into a .csv
# The variables I need: today, PantoneName, PantoneID, Hex, Word1, Word2, Word3
import csv

destname = 'Colors.csv'
#This section was only needed to add the header to the .csv
#destfile = open(destname, 'w')
#mywriter = csv.writer(destfile)
#mywriter.writerow(["Date", "PantoneName", "PantoneID", "Hex#", "Word1", "Word2", "Word3"])
#destfile.close()

destfile = open(destname, 'a')
mywriter = csv.writer(destfile)
mywriter.writerow([today, PantoneName, PantoneID, Hex, Word1, Word2, Word3])

destfile.close()

# %% [markdown]
# ## Section 2
# Using the variable names, like "PantoneName", to create new "color-item" section in the html.

# %%
# Creating the new color section
NewColor = """
<div class="color-item">
<svg height="200" width="200">
   <rect fill=
    """

NewColor2 = """
    height="200" width="200" x="0" y="0">
   </rect>
  </svg>
  <div class= "date">
   <p>
    """

NewColor3 = """
   </p>
  </div>
  <div class="text">
   <p>
    """

Break = """
    <br/>
    """
End = """
    </p>
    </div>
</div>
    """

# %%
# Making the date into a string
today_str = str(today)
today_str
# Out:
# '02/16/2018'

# %%
# Adding the color variables to the HTML text from above
NewColorHTML = [NewColor] + [Hex] + [NewColor2] + [today_str] + [NewColor3] + [PantoneName] + [Break] + [PantoneID] + [Break] + [Hex] + [End]

# %%
# Making the list into a string
NewColorHTML = "".join(NewColorHTML)
NewColorHTML
# Out:
# '\n<div class="color-item">\n<svg height="200" width="200">\n   <rect fill=\n    #BBA0CE\n    height="200" width="200" x="0" y="0">\n   </rect>\n  </svg>\n  <div class= "date">\n   <p>\n    02/16/2018\n   </p>\n  </div>\n  <div class="text">\n   <p>\n    Lavendula\n    <br/>\n    15-3620\n    <br/>\n    #BBA0CE\n    </p>\n    </div>\n</div>\n    '

# %%
#Saving the string as new HTML file
file = open("newcolor.html","w") 
file.write(NewColorHTML)
file.close()

# %% [markdown]
# ## Section 3
# Adding "newcolor.html" to "index.html" - for now "newindex.html" until it's perfect

# %%
# Now I need to add this code to index.html
# Right after <div class="colors">

# %%
# Getting the URL for my COTD archive
cotd_archive = requests.get("https://polk54.github.io/Pantone_ColorOfTheDay/")
soup2 = BeautifulSoup(cotd_archive.content, "html.parser")

# %%
# Saving the COTD archive as a new html file
with open("cotd.html", "w") as file:
    file.write(str(soup2))
    file.close()

# %%
# Opening the cotd and newcolor html files
soup3 = BeautifulSoup(open("cotd.html"), "html.parser")
soup4 = BeautifulSoup(open("newcolor.html"), "html.parser")

# %%
# Finding where the new color should go
colorsection = soup3.find(class_="color-item")

# %%
# Inserting the newcolor html - that was read using BS
colorsection.insert_before(soup4)

# %%
# Saving the file
with open("index.html", "w") as file:
    file.write(str(soup3))
